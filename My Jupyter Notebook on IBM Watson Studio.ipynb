# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mazie Alfaro__
# Data Analyst

# %% [markdown]
# _I'm interested in data science because it helps us analyze metadata_

# %% [markdown]
# ### I will make a simple computation below

# %%
1+1*5
# Out:
# 6

# %% [markdown]
# Bulleted List
# * line 1
# * line 2
# * line 3
#
# Numbered list
# 1. Line 1
# 2. Line 2
# 3. Line 3
# 4. Line 4
#
# ~~Strikethrough~~
